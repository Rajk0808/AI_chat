# %%
import pandas as pd

# %%
data = pd.read_json("arthritis_questions.json")

# %%
new_data = {}

# %%
for question in data['questions']:
    print(question)
# Out:
# {'id': 'arthritis_001', 'question': 'What should pet owners know about mobility in Arthritis? (Q1)', 'answer': 'This question addresses mobility related to Arthritis. Key points include recognizing early signs, applying appropriate first actions, avoiding unsafe home remedies, and seeking veterinary care when symptoms worsen or persist beyond safe limits.', 'topic': 'mobility', 'disease': 'Arthritis', 'lang': 'en'}
# {'id': 'arthritis_002', 'question': 'What should pet owners know about pain_management in Arthritis? (Q2)', 'answer': 'This question addresses pain_management related to Arthritis. Key points include recognizing early signs, applying appropriate first actions, avoiding unsafe home remedies, and seeking veterinary care when symptoms worsen or persist beyond safe limits.', 'topic': 'pain_management', 'disease': 'Arthritis', 'lang': 'en'}
# ...

# %%
# Out:
# {'id': 'arthritis_001',
#  'question': 'What should pet owners know about mobility in Arthritis? (Q1)',
#  'answer': 'This question addresses mobility related to Arthritis. Key points include recognizing early signs, applying appropriate first actions, avoiding unsafe home remedies, and seeking veterinary care when symptoms worsen or persist beyond safe limits.',
#  'topic': 'mobility',
#  'disease': 'Arthritis',
#  'lang': 'en'}
